# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./test_images/gill.jpg')
img.shape
# Out:
# (900, 1500, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (900, 1500)

# %%
gray
# Out:
# array([[172, 172, 172, ..., 120, 125, 147],
#        [172, 172, 172, ...,  51,  56,  78],
#        [172, 172, 172, ...,  36,  41,  63],
#        ...,
#        [217, 203, 200, ..., 200, 204, 206],
#        [219, 200, 193, ..., 196, 196, 201],
#        [211, 190, 179, ..., 199, 203, 203]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[659, 127, 282, 282]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (659, 127, 282, 282)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (282, 282, 3)

# %% [markdown]
# Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# (3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/gill.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/gill.jpg')
plt.imshow(cropped_image)

# %%
path_to_data = "./datasets/"
path_to_cr_data = "./datasets/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./datasets/ishan_kishan',
#  './datasets/lionel_messi',
#  './datasets/maria_sharapova',
#  './datasets/roger_federer',
#  './datasets/serena_williams',
#  './datasets/shubman_gill',
#  './datasets/virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./datasets/cropped/ishan_kishan
# Generating cropped images in folder:  ./datasets/cropped/lionel_messi
# Generating cropped images in folder:  ./datasets/cropped/maria_sharapova
# Generating cropped images in folder:  ./datasets/cropped/roger_federer
# Generating cropped images in folder:  ./datasets/cropped/serena_williams
# Generating cropped images in folder:  ./datasets/cropped/shubman_gill
# libpng warning: iCCP: known incorrect sRGB profile
# Generating cropped images in folder:  ./datasets/cropped/virat_kohli

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'ishan_kishan': ['./datasets/cropped/ishan_kishan/ishan_kishan1.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan2.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan3.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan4.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan5.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan6.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan7.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan8.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan9.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan10.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan11.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan12.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan13.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan14.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan15.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan16.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan17.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan18.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan19.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan20.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan21.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan22.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan23.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan24.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan25.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan26.png',
#   './datasets/cropped/ishan_kishan/ishan_kishan27.png'],
#  'lionel_messi': ['./datasets/cropped/lionel_messi/lionel_messi1.png',
#   './datasets/cropped/lionel_messi/lionel_messi2.png',
#   './datasets/cropped/lionel_messi/lionel_messi3.png',
#   './datasets/cropped/lionel_messi/lionel_messi4.png',
#   './datasets/cropped/lionel_messi/lionel_messi5.png',
#   './datasets/cropped/lionel_messi/lionel_messi6.png',
#   './datasets/cropped/lionel_messi/lionel_messi7.png',
#   './datasets/cropped/lionel_messi/lionel_messi8.png',
#   './datasets/cropped/lionel_messi/lionel_messi9.png',
#   './datasets/cropped/lionel_messi/lionel_messi10.png',
#   './datasets/cropped/lionel_messi/lionel_messi11.png',
#   './datasets/cropped/lionel_messi/lionel_messi12.png',
#   './datasets/cropped/lionel_messi/lionel_messi13.png',
#   './datasets/cropped/lionel_messi/lionel_messi14.png',
#   './datasets/cropped/lionel_messi/lionel_messi15.png',
#   './datasets/cropped/lionel_messi/lionel_messi16.png',
#   './datasets/cropped/lionel_messi/lionel_messi17.png',
#   './datasets/cropped/lionel_messi/lionel_messi18.png',
#   './datasets/cropped/lionel_messi/lionel_messi19.png',
#   './datasets/cropped/lionel_messi/lionel_messi20.png',
#   './datasets/cropped/lionel_messi/lionel_messi21.png',
#   './datasets/cropped/lionel_messi/lionel_messi22.png',
#   './datasets/cropped/lionel_messi/lionel_messi23.png',
#   './datasets/cropped/lionel_messi/lionel_messi24.png',
#   './datasets/cropped/lionel_messi/lionel_messi25.png',
#   './datasets/cropped/lionel_messi/lionel_messi26.png',
#   './datasets/cropped/lionel_messi/lionel_messi27.png',
#   './datasets/cropped/lionel_messi/lionel_messi28.png',
#   './datasets/cropped/lionel_messi/lionel_messi29.png',
#   './datasets/cropped/lionel_messi/lionel_messi30.png',
#   './datasets/cropped/lionel_messi/lionel_messi31.png',
#   './datasets/cropped/lionel_messi/lionel_messi32.png',
#   './datasets/cropped/lionel_messi/lionel_messi33.png',
#   './datasets/cropped/lionel_messi/lionel_messi34.png',
#   './datasets/cropped/lionel_messi/lionel_messi35.png',
#   './datasets/cropped/lionel_messi/lionel_messi36.png',
#   './datasets/cropped/lionel_messi/lionel_messi37.png',
#   './datasets/cropped/lionel_messi/lionel_messi38.png',
#   './datasets/cropped/lionel_messi/lionel_messi39.png'],
#  'maria_sharapova': ['./datasets/cropped/maria_sharapova/maria_sharapova1.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova2.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova3.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova4.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova5.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova6.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova7.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova8.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova9.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova10.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova11.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova12.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova13.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova14.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova15.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova16.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova17.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova18.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova19.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova20.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova21.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova22.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova23.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova24.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova25.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova26.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova27.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova28.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova29.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova30.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova31.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova32.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova33.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova34.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova35.png'],
#  'roger_federer': ['./datasets/cropped/roger_federer/roger_federer1.png',
#   './datasets/cropped/roger_federer/roger_federer2.png',
#   './datasets/cropped/roger_federer/roger_federer3.png',
#   './datasets/cropped/roger_federer/roger_federer4.png',
#   './datasets/cropped/roger_federer/roger_federer5.png',
#   './datasets/cropped/roger_federer/roger_federer6.png',
#   './datasets/cropped/roger_federer/roger_federer7.png',
#   './datasets/cropped/roger_federer/roger_federer8.png',
#   './datasets/cropped/roger_federer/roger_federer9.png',
#   './datasets/cropped/roger_federer/roger_federer10.png',
#   './datasets/cropped/roger_federer/roger_federer11.png',
#   './datasets/cropped/roger_federer/roger_federer12.png',
#   './datasets/cropped/roger_federer/roger_federer13.png',
#   './datasets/cropped/roger_federer/roger_federer14.png',
#   './datasets/cropped/roger_federer/roger_federer15.png',
#   './datasets/cropped/roger_federer/roger_federer16.png',
#   './datasets/cropped/roger_federer/roger_federer17.png',
#   './datasets/cropped/roger_federer/roger_federer18.png',
#   './datasets/cropped/roger_federer/roger_federer19.png',
#   './datasets/cropped/roger_federer/roger_federer20.png',
#   './datasets/cropped/roger_federer/roger_federer21.png',
#   './datasets/cropped/roger_federer/roger_federer22.png',
#   './datasets/cropped/roger_federer/roger_federer23.png',
#   './datasets/cropped/roger_federer/roger_federer24.png',
#   './datasets/cropped/roger_federer/roger_federer25.png',
#   './datasets/cropped/roger_federer/roger_federer26.png',
#   './datasets/cropped/roger_federer/roger_federer27.png',
#   './datasets/cropped/roger_federer/roger_federer28.png',
#   './datasets/cropped/roger_federer/roger_federer29.png',
#   './datasets/cropped/roger_federer/roger_federer30.png'],
#  'serena_williams': ['./datasets/cropped/serena_williams/serena_williams1.png',
#   './datasets/cropped/serena_williams/serena_williams2.png',
#   './datasets/cropped/serena_williams/serena_williams3.png',
#   './datasets/cropped/serena_williams/serena_williams4.png',
#   './datasets/cropped/serena_williams/serena_williams5.png',
#   './datasets/cropped/serena_williams/serena_williams6.png',
#   './datasets/cropped/serena_williams/serena_williams7.png',
#   './datasets/cropped/serena_williams/serena_williams8.png',
#   './datasets/cropped/serena_williams/serena_williams9.png',
#   './datasets/cropped/serena_williams/serena_williams10.png',
#   './datasets/cropped/serena_williams/serena_williams11.png',
#   './datasets/cropped/serena_williams/serena_williams12.png',
#   './datasets/cropped/serena_williams/serena_williams13.png',
#   './datasets/cropped/serena_williams/serena_williams14.png',
#   './datasets/cropped/serena_williams/serena_williams15.png',
#   './datasets/cropped/serena_williams/serena_williams16.png',
#   './datasets/cropped/serena_williams/serena_williams17.png',
#   './datasets/cropped/serena_williams/serena_williams18.png',
#   './datasets/cropped/serena_williams/serena_williams19.png',
#   './datasets/cropped/serena_williams/serena_williams20.png',
#   './datasets/cropped/serena_williams/serena_williams21.png',
#   './datasets/cropped/serena_williams/serena_williams22.png',
#   './datasets/cropped/serena_williams/serena_williams23.png',
#   './datasets/cropped/serena_williams/serena_williams24.png',
#   './datasets/cropped/serena_williams/serena_williams25.png',
#   './datasets/cropped/serena_williams/serena_williams26.png',
#   './datasets/cropped/serena_williams/serena_williams27.png',
#   './datasets/cropped/serena_williams/serena_williams28.png',
#   './datasets/cropped/serena_williams/serena_williams29.png',
#   './datasets/cropped/serena_williams/serena_williams30.png',
#   './datasets/cropped/serena_williams/serena_williams31.png',
#   './datasets/cropped/serena_williams/serena_williams32.png',
#   './datasets/cropped/serena_williams/serena_williams33.png',
#   './datasets/cropped/serena_williams/serena_williams34.png',
#   './datasets/cropped/serena_williams/serena_williams35.png'],
#  'shubman_gill': ['./datasets/cropped/shubman_gill/shubman_gill1.png',
#   './datasets/cropped/shubman_gill/shubman_gill2.png',
#   './datasets/cropped/shubman_gill/shubman_gill3.png',
#   './datasets/cropped/shubman_gill/shubman_gill4.png',
#   './datasets/cropped/shubman_gill/shubman_gill5.png',
#   './datasets/cropped/shubman_gill/shubman_gill6.png',
#   './datasets/cropped/shubman_gill/shubman_gill7.png',
#   './datasets/cropped/shubman_gill/shubman_gill8.png',
#   './datasets/cropped/shubman_gill/shubman_gill9.png',
#   './datasets/cropped/shubman_gill/shubman_gill10.png',
#   './datasets/cropped/shubman_gill/shubman_gill11.png',
#   './datasets/cropped/shubman_gill/shubman_gill12.png',
#   './datasets/cropped/shubman_gill/shubman_gill13.png',
#   './datasets/cropped/shubman_gill/shubman_gill14.png',
#   './datasets/cropped/shubman_gill/shubman_gill15.png',
#   './datasets/cropped/shubman_gill/shubman_gill16.png',
#   './datasets/cropped/shubman_gill/shubman_gill17.png',
#   './datasets/cropped/shubman_gill/shubman_gill18.png',
#   './datasets/cropped/shubman_gill/shubman_gill19.png',
#   './datasets/cropped/shubman_gill/shubman_gill20.png',
#   './datasets/cropped/shubman_gill/shubman_gill21.png',
#   './datasets/cropped/shubman_gill/shubman_gill22.png',
#   './datasets/cropped/shubman_gill/shubman_gill23.png',
#   './datasets/cropped/shubman_gill/shubman_gill24.png',
#   './datasets/cropped/shubman_gill/shubman_gill25.png',
#   './datasets/cropped/shubman_gill/shubman_gill26.png',
#   './datasets/cropped/shubman_gill/shubman_gill27.png',
#   './datasets/cropped/shubman_gill/shubman_gill28.png',
#   './datasets/cropped/shubman_gill/shubman_gill29.png',
#   './datasets/cropped/shubman_gill/shubman_gill30.png',
#   './datasets/cropped/shubman_gill/shubman_gill31.png',
#   './datasets/cropped/shubman_gill/shubman_gill32.png',
#   './datasets/cropped/shubman_gill/shubman_gill33.png',
#   './datasets/cropped/shubman_gill/shubman_gill34.png',
#   './datasets/cropped/shubman_gill/shubman_gill35.png',
#   './datasets/cropped/shubman_gill/shubman_gill36.png',
#   './datasets/cropped/shubman_gill/shubman_gill37.png',
#   './datasets/cropped/shubman_gill/shubman_gill38.png',
#   './datasets/cropped/shubman_gill/shubman_gill39.png',
#   './datasets/cropped/shubman_gill/shubman_gill40.png',
#   './datasets/cropped/shubman_gill/shubman_gill41.png',
#   './datasets/cropped/shubman_gill/shubman_gill42.png',
#   './datasets/cropped/shubman_gill/shubman_gill43.png',
#   './datasets/cropped/shubman_gill/shubman_gill44.png',
#   './datasets/cropped/shubman_gill/shubman_gill45.png',
#   './datasets/cropped/shubman_gill/shubman_gill46.png',
#   './datasets/cropped/shubman_gill/shubman_gill47.png',
#   './datasets/cropped/shubman_gill/shubman_gill48.png',
#   './datasets/cropped/shubman_gill/shubman_gill49.png',
#   './datasets/cropped/shubman_gill/shubman_gill50.png',
#   './datasets/cropped/shubman_gill/shubman_gill51.png',
#   './datasets/cropped/shubman_gill/shubman_gill52.png',
#   './datasets/cropped/shubman_gill/shubman_gill53.png',
#   './datasets/cropped/shubman_gill/shubman_gill54.png',
#   './datasets/cropped/shubman_gill/shubman_gill55.png',
#   './datasets/cropped/shubman_gill/shubman_gill56.png',
#   './datasets/cropped/shubman_gill/shubman_gill57.png',
#   './datasets/cropped/shubman_gill/shubman_gill58.png',
#   './datasets/cropped/shubman_gill/shubman_gill59.png',
#   './datasets/cropped/shubman_gill/shubman_gill60.png',
#   './datasets/cropped/shubman_gill/shubman_gill61.png',
#   './datasets/cropped/shubman_gill/shubman_gill62.png',
#   './datasets/cropped/shubman_gill/shubman_gill63.png',
#   './datasets/cropped/shubman_gill/shubman_gill64.png',
#   './datasets/cropped/shubman_gill/shubman_gill65.png',
#   './datasets/cropped/shubman_gill/shubman_gill66.png',
#   './datasets/cropped/shubman_gill/shubman_gill67.png',
#   './datasets/cropped/shubman_gill/shubman_gill68.png',
#   './datasets/cropped/shubman_gill/shubman_gill69.png',
#   './datasets/cropped/shubman_gill/shubman_gill70.png',
#   './datasets/cropped/shubman_gill/shubman_gill71.png',
#   './datasets/cropped/shubman_gill/shubman_gill72.png',
#   './datasets/cropped/shubman_gill/shubman_gill73.png',
#   './datasets/cropped/shubman_gill/shubman_gill74.png',
#   './datasets/cropped/shubman_gill/shubman_gill75.png',
#   './datasets/cropped/shubman_gill/shubman_gill76.png',
#   './datasets/cropped/shubman_gill/shubman_gill77.png',
#   './datasets/cropped/shubman_gill/shubman_gill78.png',
#   './datasets/cropped/shubman_gill/shubman_gill79.png',
#   './datasets/cropped/shubman_gill/shubman_gill80.png',
#   './datasets/cropped/shubman_gill/shubman_gill81.png',
#   './datasets/cropped/shubman_gill/shubman_gill82.png',
#   './datasets/cropped/shubman_gill/shubman_gill83.png',
#   './datasets/cropped/shubman_gill/shubman_gill84.png',
#   './datasets/cropped/shubman_gill/shubman_gill85.png',
#   './datasets/cropped/shubman_gill/shubman_gill86.png'],
#  'virat_kohli': ['./datasets/cropped/virat_kohli/virat_kohli1.png',
#   './datasets/cropped/virat_kohli/virat_kohli2.png',
#   './datasets/cropped/virat_kohli/virat_kohli3.png',
#   './datasets/cropped/virat_kohli/virat_kohli4.png',
#   './datasets/cropped/virat_kohli/virat_kohli5.png',
#   './datasets/cropped/virat_kohli/virat_kohli6.png',
#   './datasets/cropped/virat_kohli/virat_kohli7.png',
#   './datasets/cropped/virat_kohli/virat_kohli8.png',
#   './datasets/cropped/virat_kohli/virat_kohli9.png',
#   './datasets/cropped/virat_kohli/virat_kohli10.png',
#   './datasets/cropped/virat_kohli/virat_kohli11.png',
#   './datasets/cropped/virat_kohli/virat_kohli12.png',
#   './datasets/cropped/virat_kohli/virat_kohli13.png',
#   './datasets/cropped/virat_kohli/virat_kohli14.png',
#   './datasets/cropped/virat_kohli/virat_kohli15.png',
#   './datasets/cropped/virat_kohli/virat_kohli16.png',
#   './datasets/cropped/virat_kohli/virat_kohli17.png',
#   './datasets/cropped/virat_kohli/virat_kohli18.png',
#   './datasets/cropped/virat_kohli/virat_kohli19.png',
#   './datasets/cropped/virat_kohli/virat_kohli20.png',
#   './datasets/cropped/virat_kohli/virat_kohli21.png',
#   './datasets/cropped/virat_kohli/virat_kohli22.png',
#   './datasets/cropped/virat_kohli/virat_kohli23.png',
#   './datasets/cropped/virat_kohli/virat_kohli24.png',
#   './datasets/cropped/virat_kohli/virat_kohli25.png',
#   './datasets/cropped/virat_kohli/virat_kohli26.png',
#   './datasets/cropped/virat_kohli/virat_kohli27.png',
#   './datasets/cropped/virat_kohli/virat_kohli28.png',
#   './datasets/cropped/virat_kohli/virat_kohli29.png',
#   './datasets/cropped/virat_kohli/virat_kohli30.png',
#   './datasets/cropped/virat_kohli/virat_kohli31.png',
#   './datasets/cropped/virat_kohli/virat_kohli32.png',
#   './datasets/cropped/virat_kohli/virat_kohli33.png',
#   './datasets/cropped/virat_kohli/virat_kohli34.png',
#   './datasets/cropped/virat_kohli/virat_kohli35.png',
#   './datasets/cropped/virat_kohli/virat_kohli36.png',
#   './datasets/cropped/virat_kohli/virat_kohli37.png',
#   './datasets/cropped/virat_kohli/virat_kohli38.png',
#   './datasets/cropped/virat_kohli/virat_kohli39.png',
#   './datasets/cropped/virat_kohli/virat_kohli40.png',
#   './datasets/cropped/virat_kohli/virat_kohli41.png',
#   './datasets/cropped/virat_kohli/virat_kohli42.png',
#   './datasets/cropped/virat_kohli/virat_kohli43.png',
#   './datasets/cropped/virat_kohli/virat_kohli44.png',
#   './datasets/cropped/virat_kohli/virat_kohli45.png',
#   './datasets/cropped/virat_kohli/virat_kohli46.png',
#   './datasets/cropped/virat_kohli/virat_kohli47.png',
#   './datasets/cropped/virat_kohli/virat_kohli48.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'ishan_kishan': 0,
#  'lionel_messi': 1,
#  'maria_sharapova': 2,
#  'roger_federer': 3,
#  'serena_williams': 4,
#  'shubman_gill': 5,
#  'virat_kohli': 6}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])
# Out:
# [ WARN:0@948.936] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/ishan_kishan/ishan_kishan1.png'): can't open/read file: check file path/integrity
# [ WARN:0@948.951] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/ishan_kishan/ishan_kishan8.png'): can't open/read file: check file path/integrity
# [ WARN:0@948.953] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/ishan_kishan/ishan_kishan10.png'): can't open/read file: check file path/integrity
# [ WARN:0@948.954] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/ishan_kishan/ishan_kishan11.png'): can't open/read file: check file path/integrity
# [ WARN:0@948.990] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/ishan_kishan/ishan_kishan15.png'): can't open/read file: check file path/integrity
# [ WARN:0@948.990] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/ishan_kishan/ishan_kishan16.png'): can't open/read file: check file path/integrity
# [ WARN:0@948.990] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/ishan_kishan/ishan_kishan17.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.014] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/ishan_kishan/ishan_kishan24.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.175] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/lionel_messi/lionel_messi12.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.289] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/lionel_messi/lionel_messi30.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.299] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/lionel_messi/lionel_messi36.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.299] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/lionel_messi/lionel_messi37.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.303] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/maria_sharapova/maria_sharapova1.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.303] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/maria_sharapova/maria_sharapova2.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.303] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/maria_sharapova/maria_sharapova3.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.338] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/maria_sharapova/maria_sharapova9.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.340] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/maria_sharapova/maria_sharapova12.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.345] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/maria_sharapova/maria_sharapova16.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.434] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/maria_sharapova/maria_sharapova30.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.436] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/maria_sharapova/maria_sharapova32.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.519] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/roger_federer/roger_federer24.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.519] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/roger_federer/roger_federer25.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.522] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/roger_federer/roger_federer28.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.534] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/serena_williams/serena_williams1.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.566] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/serena_williams/serena_williams5.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.594] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/serena_williams/serena_williams12.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.597] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/serena_williams/serena_williams15.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.787] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/serena_williams/serena_williams21.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.787] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/serena_williams/serena_williams22.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.788] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/serena_williams/serena_williams24.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.803] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/serena_williams/serena_williams28.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.814] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/serena_williams/serena_williams34.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.830] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill8.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.874] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill24.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.874] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill25.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.969] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill41.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.969] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill42.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.971] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill44.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.986] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill50.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.992] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill53.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.993] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill55.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.993] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill56.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.997] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill60.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.997] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill61.png'): can't open/read file: check file path/integrity
# [ WARN:0@949.997] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill62.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.011] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill69.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.011] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill70.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.011] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill71.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.037] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill79.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.046] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/shubman_gill/shubman_gill82.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.068] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/virat_kohli/virat_kohli3.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.108] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/virat_kohli/virat_kohli22.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.108] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/virat_kohli/virat_kohli23.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.108] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/virat_kohli/virat_kohli24.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.134] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/virat_kohli/virat_kohli28.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.134] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/virat_kohli/virat_kohli29.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.144] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/virat_kohli/virat_kohli39.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.150] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/virat_kohli/virat_kohli43.png'): can't open/read file: check file path/integrity
# [ WARN:0@950.165] global loadsave.cpp:248 findDecoder imread_('./datasets/cropped/virat_kohli/virat_kohli46.png'): can't open/read file: check file path/integrity

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (241, 4096)

# %%
X[0]
# Out:
# array([ 56.,  62.,  68., ..., 249., 215.,   0.])

# %%
#import modules for training model

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test,y_test)
# Out:
# 0.7540983606557377

# %%
print(classification_report(y_test,pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.17      0.29         6
#            1       0.50      0.60      0.55         5
#            2       0.60      0.43      0.50         7
#            3       1.00      0.50      0.67         8
#            4       1.00      1.00      1.00         8
#            5       0.74      1.00      0.85        20
#            6       0.70      1.00      0.82         7
#
#     accuracy                           0.75        61
#    macro avg       0.79      0.67      0.67        61
# weighted avg       0.79      0.75      0.72        61

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.827778
# 1        random_forest    0.711111
# 2  logistic_regression    0.811111
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9016393442622951

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.639344262295082

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8524590163934426

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 5,  0,  0,  0,  0,  1,  0],
#        [ 0,  4,  0,  0,  0,  0,  1],
#        [ 0,  0,  7,  0,  0,  0,  0],
#        [ 0,  1,  1,  5,  0,  1,  0],
#        [ 0,  0,  0,  0,  8,  0,  0],
#        [ 0,  0,  0,  0,  1, 19,  0],
#        [ 0,  0,  0,  0,  0,  0,  7]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'ishan_kishan': 0,
#  'lionel_messi': 1,
#  'maria_sharapova': 2,
#  'roger_federer': 3,
#  'serena_williams': 4,
#  'shubman_gill': 5,
#  'virat_kohli': 6}

# %%
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in /home/sonigaurav/anaconda3/envs/ml/lib/python3.12/site-packages (1.3.2)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
